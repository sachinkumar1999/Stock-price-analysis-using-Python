# %% [markdown]
# # PROBLEM STATEMENT :
#
# For Investors to properly manage their portfolios, they need to visualize datasets, find
# useful patterns and gain valuable insights such as stock daily returns and risks.
# In this project we will use the power of python to perform stock data visualization and
# stock return calculation.
#
# For this purpose we will be using stock1.csv file

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Reading the csv file

# %%
df=pd.read_csv("stock1.csv")
df
# Out:
#             Date        AAPL          BA          T        MGM         AMZN  \
# 0     2012-01-12   60.198570   75.510002  30.120001  12.130000   175.929993
# 1     2012-01-13   59.972858   74.599998  30.070000  12.350000   178.419998
# 2     2012-01-17   60.671429   75.239998  30.250000  12.250000   181.660004
# 3     2012-01-18   61.301430   75.059998  30.330000  12.730000   189.440002
# 4     2012-01-19   61.107143   75.559998  30.420000  12.800000   194.449997
# ...          ...         ...         ...        ...        ...          ...
# 2154  2020-08-05  440.250000  174.279999  29.850000  16.719999  3205.030029
# 2155  2020-08-06  455.609985  172.199997  29.840000  18.459999  3225.000000
# 2156  2020-08-07  444.450012  170.020004  30.020000  19.030001  3167.459961
# 2157  2020-08-10  450.910004  179.410004  30.200001  21.650000  3148.159912
# 2158  2020-08-11  437.500000  180.130005  30.200001  21.500000  3080.669922
#
#              IBM         TSLA         GOOG        sp500
# ...

# %% [markdown]
# # Number of stocks

# %%
df.shape
# Out:
# (2159, 10)

# %% [markdown]
# # Name of the stocks

# %%
for i in range(1,10):
    print(df.columns[i])
# Out:
# AAPL
# BA
# T
# MGM
# AMZN
# IBM
# TSLA
# GOOG
# sp500

# %% [markdown]
# # Average of  sp500 stock

# %%
df['sp500'].mean()
# Out:
# 2218.7495540592877

# %% [markdown]
# # Stock having minimum dispersion from the mean

# %%
df.describe()
# Out:
#               AAPL           BA            T          MGM         AMZN  \
# count  2159.000000  2159.000000  2159.000000  2159.000000  2159.000000
# mean    140.819823   189.942700    35.162899    23.105743   915.665665
# std      70.827601   103.678586     3.207490     6.963847   697.838905
# min      55.790001    67.239998    26.770000     7.140000   175.929993
# 25%      89.165714   124.015000    33.040001    18.545000   316.490005
# 50%     116.599998   142.419998    34.930000    23.780001   676.010010
# 75%     175.019997   297.044998    37.419998    28.430000  1593.645019
# max     455.609985   440.619995    43.470001    38.029999  3225.000000
#
#                IBM         TSLA         GOOG        sp500
# count  2159.000000  2159.000000  2159.000000  2159.000000
# mean    161.853001   259.600815   783.712512  2218.749554
# std      25.561938   210.988003   334.448057   537.321727
# min      94.769997    22.790001   278.481171  1278.040039
# ...

# %% [markdown]
# # Maximum price for the amazon stock

# %%
df['AMZN'].max()
# Out:
# 3225.0

# %% [markdown]
# # Checking null values

# %%
df.isna().sum()
# Out:
# Date     0
# AAPL     0
# BA       0
# T        0
# MGM      0
# AMZN     0
# IBM      0
# TSLA     0
# GOOG     0
# sp500    0
# dtype: int64

# %% [markdown]
# # Dataframe information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2159 entries, 0 to 2158
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2159 non-null   object
#  1   AAPL    2159 non-null   float64
#  2   BA      2159 non-null   float64
#  3   T       2159 non-null   float64
#  4   MGM     2159 non-null   float64
#  5   AMZN    2159 non-null   float64
#  6   IBM     2159 non-null   float64
#  7   TSLA    2159 non-null   float64
#  8   GOOG    2159 non-null   float64
#  9   sp500   2159 non-null   float64
# dtypes: float64(9), object(1)
# memory usage: 168.8+ KB

# %% [markdown]
# # Function to plot raw stock prices(without normalization/without scaling)

# %%
df.plot(x='Date',y='AAPL')
df.plot(x='Date',y='BA')
df.plot(x='Date',y='T')
df.plot(x='Date',y='MGM')
df.plot(x='Date',y='AMZN')
df.plot(x='Date',y='IBM')
df.plot(x='Date',y='TSLA')
df.plot(x='Date',y='GOOG')
df.plot(x='Date',y='sp500')

# %%
df.plot()

# %% [markdown]
# # Data visualization with normalization and scaling

# %%
df2=df.copy()
df2.drop(columns=['Date'],inplace=True)
df2
# Out:
#             AAPL          BA          T        MGM         AMZN         IBM  \
# 0      60.198570   75.510002  30.120001  12.130000   175.929993  180.550003
# 1      59.972858   74.599998  30.070000  12.350000   178.419998  179.160004
# 2      60.671429   75.239998  30.250000  12.250000   181.660004  180.000000
# 3      61.301430   75.059998  30.330000  12.730000   189.440002  181.070007
# 4      61.107143   75.559998  30.420000  12.800000   194.449997  180.520004
# ...          ...         ...        ...        ...          ...         ...
# 2154  440.250000  174.279999  29.850000  16.719999  3205.030029  125.449997
# 2155  455.609985  172.199997  29.840000  18.459999  3225.000000  126.120003
# 2156  444.450012  170.020004  30.020000  19.030001  3167.459961  124.959999
# 2157  450.910004  179.410004  30.200001  21.650000  3148.159912  127.110001
# 2158  437.500000  180.130005  30.200001  21.500000  3080.669922  126.750000
#
#              TSLA         GOOG        sp500
# ...

# %%
import os
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2=pd.DataFrame(scaler.fit_transform(df2),
            columns=df2.columns, index=df2.index) 
print(df2)
# Out:
#           AAPL        BA         T       MGM      AMZN       IBM      TSLA  \
# 0     0.011026  0.022149  0.200599  0.161541  0.000000  0.708750  0.003370
# 1     0.010462  0.019712  0.197605  0.168663  0.000817  0.697265  0.000000
# 2     0.012209  0.021426  0.208383  0.165426  0.001879  0.704206  0.002352
# 3     0.013785  0.020944  0.213174  0.180965  0.004431  0.713046  0.002481
# 4     0.013299  0.022283  0.218563  0.183231  0.006074  0.708502  0.002450
# ...        ...       ...       ...       ...       ...       ...       ...
# 2154  0.961583  0.286678  0.184431  0.310133  0.993450  0.253491  0.902494
# 2155  1.000000  0.281108  0.183832  0.366462  1.000000  0.259027  0.905309
# 2156  0.972088  0.275269  0.194611  0.384914  0.981129  0.249442  0.882552
# 2157  0.988245  0.300418  0.205389  0.469731  0.974799  0.267206  0.861481
# 2158  0.954705  0.302346  0.205389  0.464875  0.952664  0.264232  0.834213
#
#           GOOG     sp500
# 0     0.027258  0.008282
# ...

# %%
df2.plot()

# %% [markdown]
# # Interactive data visualization using plotly (without normalized/without scaling)

# %%
sns.boxplot(df['AAPL'])

# %%
sns.boxplot(df['BA'])

# %%
sns.boxplot(df['T'])

# %%
sns.boxplot(df['AMZN'])

# %%
sns.boxplot(df['IBM'])

# %%
sns.boxplot(df['GOOG'])

# %%
sns.boxplot(df['sp500'])

# %% [markdown]
# # It seems that most stocks experienced massive drops in 2020, let's assume
# # that you own 100 shares of the S&P500 and you bought them on Feb 19th,2020.
# How much did you lose (in $) by March 23rd, 2020?

# %%
df[df['Date']=='2020-02-19']['sp500']
# Out:
# 2037    3386.149902
# Name: sp500, dtype: float64

# %%
df[df['Date']=='2020-03-23']['sp500']
# Out:
# 2060    2237.399902
# Name: sp500, dtype: float64

# %%
loss=3386.149902-2237.399902
loss
# Out:
# 1148.75

# %% [markdown]
# # Daily return for S&P 500 stock

# %%
sp500_daily_returns = df['sp500'].pct_change()
sp500_daily_returns*100
# Out:
# 0            NaN
# 1      -0.494792
# 2       0.355295
# 3       1.110793
# 4       0.493866
#           ...
# 2154    0.642974
# 2155    0.642770
# 2156    0.063303
# 2157    0.274222
# 2158   -0.796913
# Name: sp500, Length: 2159, dtype: float64

# %% [markdown]
# # Daily return for Amazon stock

# %%
amazon_daily_returns = df['AMZN'].pct_change()
amazon_daily_returns*100
# Out:
# 0            NaN
# 1       1.415339
# 2       1.815943
# 3       4.282725
# 4       2.644634
#           ...
# 2154    2.109065
# 2155    0.623082
# 2156   -1.784187
# 2157   -0.609323
# 2158   -2.143792
# Name: AMZN, Length: 2159, dtype: float64

# %% [markdown]
# # Calculate stocks daily returns (for all stocks)

# %%
apple_daily_returns = df['AAPL'].pct_change()
print(apple_daily_returns*100)
print('---------------------------------------')
ba_daily_returns = df['BA'].pct_change()
print(ba_daily_returns*100)
print('---------------------------------------')
T_daily_returns = df['T'].pct_change()
print(T_daily_returns*100)
print('---------------------------------------')
mgm_daily_returns = df['MGM'].pct_change()
print(mgm_daily_returns*100)
print('---------------------------------------')
amazon_daily_returns = df['AMZN'].pct_change()
print(amazon_daily_returns*100)
print('---------------------------------------')
ibm_daily_returns = df['IBM'].pct_change()
print(ibm_daily_returns*100)
print('---------------------------------------')
tsla_daily_returns = df['TSLA'].pct_change()
print(tsla_daily_returns*100)
print('---------------------------------------')
goog_daily_returns = df['GOOG'].pct_change()
print(goog_daily_returns*100)
print('---------------------------------------')
sp500_daily_returns = df['sp500'].pct_change()
print(sp500_daily_returns*100)
# Out:
# 0            NaN
# 1      -0.374946
# 2       1.164812
# 3       1.038382
# 4      -0.316937
#           ...
# 2154    0.362467
# 2155    3.488923
# 2156   -2.449458
# 2157    1.453480
# 2158   -2.973987
# Name: AAPL, Length: 2159, dtype: float64
# ---------------------------------------
# 0            NaN
# 1      -1.205144
# 2       0.857909
# 3      -0.239234
# 4       0.666134
#           ...
# 2154    5.579446
# 2155   -1.193483
# 2156   -1.265966
# 2157    5.522880
# 2158    0.401316
# Name: BA, Length: 2159, dtype: float64
# ---------------------------------------
# 0            NaN
# 1      -0.166006
# 2       0.598603
# 3       0.264463
# 4       0.296736
#           ...
# 2154   -0.533156
# 2155   -0.033501
# 2156    0.603217
# 2157    0.599604
# 2158    0.000000
# Name: T, Length: 2159, dtype: float64
# ---------------------------------------
# 0             NaN
# 1        1.813685
# 2       -0.809717
# 3        3.918367
# 4        0.549882
#           ...
# ...

# %% [markdown]
# # Plot the Daily returns vs. time graph using both static and interactive plots

# %%
apple_daily_returns = df['AAPL'].pct_change()
sns.distplot(apple_daily_returns.dropna(),bins=50,color='blue')

# %%
ba_daily_returns = df['BA'].pct_change()

sns.distplot(ba_daily_returns.dropna(),bins=50,color='blue')

# %%
t_daily_returns = df['T'].pct_change()

sns.distplot(t_daily_returns.dropna(),bins=50,color='blue')

# %%
mgm_daily_returns = df['MGM'].pct_change()

sns.distplot(mgm_daily_returns.dropna(),bins=50,color='blue')

# %%
amazon_daily_returns = df['AMZN'].pct_change()

sns.distplot(amazon_daily_returns.dropna(),bins=50,color='blue')

# %%
ibm_daily_returns = df['IBM'].pct_change()

sns.distplot(ibm_daily_returns.dropna(),bins=50,color='blue')

# %%
tesla_daily_returns = df['TSLA'].pct_change()

sns.distplot(tesla_daily_returns.dropna(),bins=50,color='blue')

# %%
google_daily_returns = df['GOOG'].pct_change()

sns.distplot(google_daily_returns.dropna(),bins=50,color='blue')

# %%
sp500_daily_returns = df['sp500'].pct_change()

sns.distplot(sp500_daily_returns.dropna(),bins=50,color='blue')

# %% [markdown]
# # Correlation between Daily returns of all stocks

# %%
df1=df.copy()

# %%
df1['AAPL']=df['AAPL'].pct_change()
df1['BA']=df['BA'].pct_change()
df1['T']=df['T'].pct_change()
df1['MGM']=df['MGM'].pct_change()
df1['AMZN']=df['AMZN'].pct_change()
df1['IBM']=df['IBM'].pct_change()
df1['TSLA']=df['TSLA'].pct_change()
df1['GOOG']=df['GOOG'].pct_change()
df1['sp500']=df['sp500'].pct_change()

df1
# Out:
#             Date      AAPL        BA         T       MGM      AMZN       IBM  \
# 0     2012-01-12       NaN       NaN       NaN       NaN       NaN       NaN
# 1     2012-01-13 -0.003749 -0.012051 -0.001660  0.018137  0.014153 -0.007699
# 2     2012-01-17  0.011648  0.008579  0.005986 -0.008097  0.018159  0.004689
# 3     2012-01-18  0.010384 -0.002392  0.002645  0.039184  0.042827  0.005944
# 4     2012-01-19 -0.003169  0.006661  0.002967  0.005499  0.026446 -0.003038
# ...          ...       ...       ...       ...       ...       ...       ...
# 2154  2020-08-05  0.003625  0.055794 -0.005332  0.000000  0.021091 -0.003099
# 2155  2020-08-06  0.034889 -0.011935 -0.000335  0.104067  0.006231  0.005341
# 2156  2020-08-07 -0.024495 -0.012660  0.006032  0.030878 -0.017842 -0.009198
# 2157  2020-08-10  0.014535  0.055229  0.005996  0.137677 -0.006093  0.017206
# 2158  2020-08-11 -0.029740  0.004013  0.000000 -0.006928 -0.021438 -0.002832
#
#           TSLA      GOOG     sp500
# ...

# %%
df1.corr()
# Out:
#            AAPL        BA         T       MGM      AMZN       IBM      TSLA  \
# AAPL   1.000000  0.385249  0.341373  0.384088  0.410233  0.434534  0.288534
# BA     0.385249  1.000000  0.401602  0.554229  0.267466  0.479264  0.250946
# T      0.341373  0.401602  1.000000  0.340166  0.233145  0.484219  0.152515
# MGM    0.384088  0.554229  0.340166  1.000000  0.309016  0.441631  0.311879
# AMZN   0.410233  0.267466  0.233145  0.309016  1.000000  0.339589  0.310083
# IBM    0.434534  0.479264  0.484219  0.441631  0.339589  1.000000  0.245610
# TSLA   0.288534  0.250946  0.152515  0.311879  0.310083  0.245610  1.000000
# GOOG   0.509124  0.388048  0.353695  0.439141  0.575283  0.458816  0.322804
# sp500  0.657320  0.641826  0.617463  0.631449  0.539560  0.703935  0.387920
#
#            GOOG     sp500
# AAPL   0.509124  0.657320
# BA     0.388048  0.641826
# T      0.353695  0.617463
# MGM    0.439141  0.631449
# AMZN   0.575283  0.539560
# IBM    0.458816  0.703935
# ...

# %% [markdown]
# # Using  Heatmap:
#
# What are the top 2 stocks that are positively correlated with the S&P500?
# What is the correlation between Amazon and Boeing? Comment on your answer
# What is the correlation between MGM and Boeing? Comment on your answer

# %%
from statsmodels import api as sm
correletion=df1.corr()
sm.graphics.plot_corr(correletion,xnames=list(correletion.columns))
plt.show()

# %% [markdown]
# # Histogram for daily returns

# %%
print(plt.hist(df1['AAPL']))
# Out:
# (array([   2.,    4.,   10.,   61.,  618., 1276.,  158.,   19.,    7.,
#           3.]), array([-0.12864695, -0.10380143, -0.07895591, -0.05411039, -0.02926487,
#        -0.00441934,  0.02042618,  0.0452717 ,  0.07011722,  0.09496274,
#         0.11980826]), <a list of 10 Patch objects>)

# %%
plt.hist(df1['BA'])
# Out:
# (array([1.000e+00, 4.000e+00, 3.000e+00, 3.200e+01, 1.166e+03, 9.230e+02,
#         1.500e+01, 1.000e+01, 2.000e+00, 2.000e+00]),
#  array([-0.23848412, -0.1903171 , -0.14215008, -0.09398306, -0.04581605,
#          0.00235097,  0.05051799,  0.09868501,  0.14685202,  0.19501904,
#          0.24318606]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df1['T'])
# Out:
# (array([4.000e+00, 6.000e+00, 2.200e+01, 1.180e+02, 1.249e+03, 7.100e+02,
#         3.900e+01, 7.000e+00, 2.000e+00, 1.000e+00]),
#  array([-0.0924102 , -0.07314683, -0.05388347, -0.0346201 , -0.01535673,
#          0.00390663,  0.02317   ,  0.04243336,  0.06169673,  0.08096009,
#          0.10022346]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df1['MGM'])
# Out:
# (array([1.000e+00, 1.000e+00, 1.000e+00, 1.800e+01, 8.720e+02, 1.233e+03,
#         2.700e+01, 3.000e+00, 1.000e+00, 1.000e+00]),
#  array([-0.3361399 , -0.26941115, -0.20268241, -0.13595367, -0.06922492,
#         -0.00249618,  0.06423257,  0.13096131,  0.19769005,  0.2644188 ,
#          0.33114754]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df1['AMZN'])
# Out:
# (array([   4.,   16.,   69.,  735., 1176.,  130.,   17.,    7.,    0.,
#            4.]),
#  array([-0.10997247, -0.08322953, -0.05648658, -0.02974363, -0.00300068,
#          0.02374227,  0.05048522,  0.07722817,  0.10397112,  0.13071407,
#          0.15745701]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df1['IBM'])
# Out:
# (array([1.000e+00, 3.000e+00, 8.000e+00, 3.500e+01, 3.960e+02, 1.559e+03,
#         1.380e+02, 1.200e+01, 5.000e+00, 1.000e+00]),
#  array([-0.12850727, -0.10435549, -0.08020371, -0.05605194, -0.03190016,
#         -0.00774838,  0.0164034 ,  0.04055518,  0.06470696,  0.08885873,
#          0.11301051]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df1['TSLA'])
# Out:
# (array([4.000e+00, 9.000e+00, 4.500e+01, 3.840e+02, 1.334e+03, 3.160e+02,
#         4.600e+01, 9.000e+00, 1.000e+01, 1.000e+00]),
#  array([-0.1932743 , -0.14955182, -0.10582933, -0.06210685, -0.01838436,
#          0.02533812,  0.06906061,  0.11278309,  0.15650557,  0.20022806,
#          0.24395054]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df1['GOOG'])
# Out:
# (array([1.00e+00, 6.00e+00, 5.30e+01, 7.37e+02, 1.28e+03, 6.70e+01,
#         7.00e+00, 5.00e+00, 0.00e+00, 2.00e+00]),
#  array([-0.1110082 , -0.08385494, -0.05670169, -0.02954844, -0.00239519,
#          0.02475806,  0.05191131,  0.07906456,  0.10621781,  0.13337106,
#          0.16052431]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df1['sp500'])
# Out:
# (array([1.000e+00, 1.000e+00, 2.000e+00, 9.000e+00, 1.250e+02, 1.716e+03,
#         2.890e+02, 1.000e+01, 3.000e+00, 2.000e+00]),
#  array([-0.11984055, -0.09847372, -0.07710689, -0.05574006, -0.03437324,
#         -0.01300641,  0.00836042,  0.02972725,  0.05109408,  0.07246091,
#          0.09382774]),
#  <a list of 10 Patch objects>)

# %%
df1.plot()

# %% [markdown]
# # Based on the histogram, which of the following stocks are more risky? T or TSLA

# %% [markdown]
# 'TSLA' stock prices are more risky than 'T' beacusde there are more chances of decreasing the 'TSLA ' stock prices while 'T ' have less chances of decreasing stock prices

# %% [markdown]
# # FINISHED !!!!
